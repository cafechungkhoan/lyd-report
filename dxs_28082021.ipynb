# %% [markdown]
# # **LYD - Comment Sentiment Analysis**
#
# *LYD là hệ thống áp dụng Deep Learning dùng để quét, tóm tắt, phân tích và dự báo cảm xúc của nhà đầu tư. Với mục đích hỗ trợ nghiệp vụ tư vấn IR (Investor Relation)*
#
# **Dữ liệu input**:
# là dữ liệu bình luận (text) của nhà đầu tư trên mạng xã hội và các diễn đàn chứng khoán lớn. Quy mô tracking 700k user
#
# **Các Model áp dụng**:
# Bert, transformer, SVM, PhoBERT
#
# ### **LYD trả lời các câu hỏi chính**:
# * **Mã cổ phiếu của doanh nghiệp có được nhà đầu tư yêu thích không?** (Áp dụng Text Classification Model xác định trạng thái cảm xúc của nhà đầu tư hiện tại là tích cực (hài lòng) hay tiêu cực (không hài lòng) về cổ phiếu YYY được xác định trước.)
# * **Nhà đầu tư đang bàn tán gì về cổ phiếu doanh nghiệp?** (Áp dụng Topic Cluster Model phân loại các chủ đề chính cơ bản / kĩ thuật / thời sự & vĩ mô / tin đồn) của cổ phiếu YYY được xác định trước.)
# * **Đâu là chủ đề nhà đầu tư thích nhất về cổ phiếu?** (Áp dụng BERT Text Summarize để tóm tắt nội dung comment)
#
# ---

# %%
# Out:
# Nhập mã cần search: dxs
# Nhập giới hạn comment: 1000

# %%
# Out:
# standardized data...
# Processing step 1: Lower Case, Removed Https tag, Removed Stopwords
# CPU times: user 1.04 ms, sys: 1e+03 ns, total: 1.04 ms
# Wall time: 1.06 ms
# CPU times: user 1.64 ms, sys: 80 µs, total: 1.72 ms
# Wall time: 1.73 ms
# CPU times: user 1.1 ms, sys: 0 ns, total: 1.1 ms
# Wall time: 1.1 ms
# Done
# Processing step 3: Tokenize
# Processing step 4: POS Tagging
# Processing step 5: Entity Regconize
# Processing step 6: Vectorize PhoBERT
# Process model SVM....
# >>> Done

# %%
# Out:
# Số bình luận =  272 . Số người tham gia bình luận =  186 . Median comment / user =  1.0
# Text(0.5, 1.0, 'ViolinPlot số lượng comment của người tham gia bình luận')

# %%
# Out:
# Text(0.5, 1.0, 'Topic Tin đồn')

# %%
# Out:
# Số comment cơ bản =  31 . Số người tham gia comment =  30
# Số comment kĩ thuật =  10 . Số người tham gia comment =  9
# Số comment thời sự & vĩ mô =  6 . Số người tham gia comment =  6
# Số comment tin đồn =  42 . Số người tham gia comment =  41

# %% [markdown]
# ## **Text Summarization using BERT**

# %%
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
# Out:
#     index  ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Text Summarize
# 0   0      ...  📈𝗡𝗵𝗮̣̂𝗻 đ𝗶̣𝗻𝗵 𝘁𝗵𝗶̣ 𝘁𝗿𝘂̛𝗼̛̀𝗻𝗴 𝟮𝟳/𝟬𝟴:📈\n- Vnindex đóng cửa giảm -8.43 điểm (-0.64%) về 1301.12 điểm. - Về dòng tiền tuy có áp lực bán từ VN30 và Bank nhưng dòng tiền cũng dịch chuyển sang các nhóm ngành khác như Cảng, dệt may, đạm, năng lượng ... chứ không có dấu hiệu rút ra khỏi thị trường.
# 1   2      ...  Chuyển sàn sang Hose có gì ưu điểm hơn không các bác?
# 22  154    ...  Bàn về DXS\n\n- Người mua IPO: buồn bực vì cổ phiếu lên sàn = giá IPO, biết thế chờ lên sàn rồi hẵng mua, đỡ kẹp lâu. Một kiểu nữa là mong nó sàn vài cây để hốt nên hùa theo dìm. - Về lùm xùm tai tiếng: Nếu ai làm tư vấn niêm yết và làm dịch vụ tạo thanh khoản cho cổ phiếu trên sàn, đều biết để 1 cổ phiếu được nhiều người biết tới, bàn tán, bình phẩm, khen chê, tò mò, quan tâm nhiều như DXS là cực khó, mất vài năm trên sàn, biết bao nhiêu báo cáo định giá, bao nhiêu đội nhóm, zalo room phím hàng, lùa gà .... may ra mới có lượng cầu lớn như vậy. #HoangMai #ChungKhoanVietNam #DXS #IPO
# 23  157    ...  Có sàn 10 phiên e cũng ko mua thề... lãnh đạo bần còn bẩn nữa ... chúc dxs về giá dưới 10k
# 24  158    ...  Con này phải sàn 10 phiên, lãnh đạo DXG cũng là 1 thôi, bản chất rồi
# 25  160    ...  Mọi người nên chọn các công ty tốt lãnh đạo có tâm có tầm để đầu tư tránh các công ty có lãnh đạo lươn lẹo , lừa dối nhà đầu tư như trường hợp của Lươn Trí Thìn.
# 26  161    ...  Mấy ông đang giữ hàng chắc đang mong nó lên lắm đúng không nếu cty có ban lãnh đạo tốt thì tím phiên này, còn đối với thằng lươn này thì 3 key sàn nhé, mai ai thoát được thoát sớm, cty mẹ nó còn giá 22 mà dxs này 15
# 27  166    ...  Con hàng rẻ rách + lái lợn bẩn thỉu nhà DXG cũng đòi ipo giá 32. Ae tẩy chay mạnh loại cp dxg dxs này ra nhé
# 28  178    ...  Cp mà suốt ngày lướt fb, web... thấy pr còn hơn cả shoppe pr , trong khi cty lãnh đạo như cái quần què mất uy tín.
# 29  179    ...  Lãnh đạo cứ tối ngày bắt tay Lươn Capital để úp bô nhỏ lẻ, tư xả sàn 3 phiên đến IPO cung úp nốt. Dĩ nhiên ai cũng biết hành động dơ bẩn này là đạp gom giá rẻ xong lại bơm thổi lên cho ai ko hiểu thì tham đu vô.
# 30  193    ...  Nó cho mấy bố vào xong nó úp bô.
# 31  199    ...  Thông cảm cho NĐT mua IPO DXS. Om vốn mấy tháng trời, lên sàn đúng thời điểm chỉnh giảm mạnh của TT.
# 32  202    ...  Nhĩn DXG làm gương, lãnh đạo là một cái quan trọng nhất để đầu tư vào cổ phiếu đặc biệt ở Việt Nam
# 33  203    ...  😂 Ai vừa ôm 40x thế. Mé bán giấy ko.
# 34  208    ...  Các bác cho e hỏi con này với con DXG thì khác gì nhau, hay kiểu một vỏ 2 lòng.
# 35  219    ...  Ipo này cứ úp bô về giá 12-15 cũng lời chán
# 36  220    ...  Cho nó về giá 10 đi, đi lùa gà ah. Hãy bắt đầu bằng giá phổ thông đi, ngon thì đi lên thôi.
# 37  222    ...  Bị họ nhà Lươn ... úp bô roài.
# 38  237    ...  Tay trái qua tay phải dụ gà thôi.
# 39  249    ...  con này đáng giá penny 7.x vì đéo có trò gì.
# 40  254    ...  Anh Thìn lại bỏ tiền ra lùa gà
# 41  271    ...  None
#
# [42 rows x 5 columns]
