# %% [markdown]
# <a href="https://colab.research.google.com/github/cafechungkhoan/lyd-report/blob/main/AGG_23092021_News.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LYD - News Auto Report**
#
# * Xác định số lượng bài báo theo thời gian
# * Xác định độ yêu thích bài báo theo thời gian
# * Xác định các nguồn đăng của bài báo
# * Topic Cluster & Keyword Maps

# %%
a = input('Nhập mã cần search: ')
# Out:
# Nhập mã cần search: agg

# %%
# Out:
#                                                                                                                            title  ...      month
# 0   Hàng 'chất đống' nhưng giá BĐS vẫn không giảm                                                                                 ... 2021-09-01
# 1   "Sóng" cổ phiếu bất động sản phải chờ đến năm 2022?                                                                           ... 2021-09-01
# 2   20 doanh nghiệp niêm yết tồn kho bất động sản "chất đống" 315.000 tỷ đồng                                                     ... 2021-09-01
# 3   AGG: Thông báo giao dịch cổ phiếu của người nội bộ YAMAGUCHI MASAKAZU                                                         ... 2021-09-01
# 4   AGG: Thông báo giao dịch cổ phiếu của tổ chức có liên quan đến người nội bộ Hourai ConsulTing LTD                             ... 2021-09-01
# 5   Doanh nghiệp bất động sản tìm cách “vượt” Covid-19 trong bối cảnh dịch bệnh còn kéo dài                                       ... 2021-09-01
# 6   AGG: Giải trình biến động KQKD soát xét bán niên năm 2021 so với cùng kỳ năm trước                                            ... 2021-08-01
# 7   Nợ vay và tồn kho của doanh nghiệp BĐS nhà ở ‘phình to’ ra sao?                                                               ... 2021-08-01
# 8   Cổ phiếu địa ốc "tốt lỏi"                                                                                                     ... 2021-08-01
# 9   Những ông lớn địa ốc nào đang sở hữu quỹ đất lớn ở khu vực phía Nam?                                                          ... 2021-08-01
# 10  Hàng loạt ông lớn bất động sản lãi đậm nửa đầu năm 2021                                                                       ... 2021-08-01
# 11  Cổ phiếu cần quan tâm ngày 10/8                                                                                               ... 2021-08-01
# 12  AGG: Doanh thu An Gia nửa đầu năm gấp 10 lần cùng kỳ                                                                          ... 2021-08-01
# 13  Chuyển động quỹ đầu tư tuần 26-31/7: Dragon Capital mua AGG, Lumen Vietnam Fund không còn là cổ đông lớn tại Long Hậu         ... 2021-08-01
# 14  Nhiều “ông lớn” địa ốc kỳ vọng sức bật mạnh hậu Covid-19 nhờ quỹ đất, sức khoẻ tài chính tốt                                  ... 2021-07-01
# 15  AGG: Giải trình chênh lệch lợi nhuận sau thuế quý 2/2021 so với quý 2/2020                                                    ... 2021-07-01
# 16  AGG: Báo cáo tình hình quản trị công ty 6 tháng đầu năm 2021                                                                  ... 2021-07-01
# 17  AGG: Dragon Capital gom 10% vốn tại An Gia sau khi Creed Group rời đi                                                         ... 2021-07-01
# 18  AGG: Báo cáo thay đổi về sở hữu của nhóm nhà đầu tư nước ngoài có liên quan là cổ đông lớn                                    ... 2021-07-01
# 19  AGG: Nâng room khối ngoại thêm 1% có đủ lực làm cổ phiếu AGG “bốc đầu” (!?)                                                   ... 2021-07-01
# 20  AGG: Thông báo công văn của VSD về điều chỉnh room của mã chứng khoán AGG                                                     ... 2021-07-01
# 21  AGG: Thông báo công văn của UBCKNN về hồ sơ thông báo tỷ lệ SHNN tối đa của AGG                                               ... 2021-07-01
# 22  AGG: Nghị quyết HĐQT về việc miễn nhiệm chức danh Thành viên Ủy Ban Kiểm toán                                                 ... 2021-07-01
# 23  AGG: Quyết định của HĐQT về việc bổ nhiệm chức danh Thành viên Ủy Ban Kiểm toán                                               ... 2021-07-01
# 24  AGG: Nghị quyết HĐQT về việc công ty nhận chuyển nhượng 160.960 cổ phần phổ thông tại CTCP Đầu tư TM và Phát triển An Tường   ... 2021-06-01
# 25  AGG: Quyết định của HĐQT về việc công ty nhận chuyển nhượng 20.500 cổ phần phổ thông tại CTCP Quản lý và Phát triển Lộc Phát  ... 2021-06-01
# 26  Doanh nghiệp bất động sản xoay vốn trong thời khó                                                                             ... 2021-06-01
# 27  DXG: Chuyện phát hành ở Đất Xanh                                                                                              ... 2021-06-01
# 28  Lọc tìm cơ hội nhóm cổ phiếu bất động sản                                                                                     ... 2021-06-01
# 29  AGG: Báo cáo về ngày không còn là cổ đông lớn Võ Ngọc Mai Trang                                                               ... 2021-06-01
#
# [30 rows x 11 columns]

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## **Xác định topic được yêu thích (top like, feedback)**

# %%
data.sort_values('totalLikes', ascending=False).head(10)
# Out:
#                                                                                                                                              title  ...      month
# 129  Nhịp Đập Thị Trường 2/12/2020: Thị trường phản ứng khá tốt sau phiên Test ngày 1/12/2020. Tiêu điểm VGI và AGG                                 ... 2020-12-01
# 122  VFA Insight - 15/12/2020: Áp lực chốt lời trên cả mid cap lẫn large cap, VN-Index hình thành mẫu hình nến Harami – Tiêu điểm SNZ               ... 2020-12-01
# 76   Nhìn Lại Tuần Qua - 05/02/2021: Ngân hàng, VIN, Bất động sản giúp VN-Index tăng điểm. Thị trường phân hóa                                      ... 2021-02-01
# 11   Cổ phiếu cần quan tâm ngày 10/8                                                                                                                ... 2021-08-01
# 58   AGG: Định giá trong vùng 43,500 - 68,000 đồng/cổ phiếu                                                                                         ... 2021-04-01
# 2    20 doanh nghiệp niêm yết tồn kho bất động sản "chất đống" 315.000 tỷ đồng                                                                      ... 2021-09-01
# 87   Nhìn lại tuần qua - 29/1/2021: VNIndex hồi phục trên diện rộng đánh dấu ngày 1 đợt nỗ lực hồi phục. Chính thức tạo đáy hay là “bẫy tăng giá”?  ... 2021-02-01
# 10   Hàng loạt ông lớn bất động sản lãi đậm nửa đầu năm 2021                                                                                        ... 2021-08-01
# 44   Doanh nghiệp địa ốc và mối lo "chết mòn" trên đống tài sản                                                                                     ... 2021-05-01
# 68   AGG: Bất động sản An Gia lên kế hoạch lãi 500 tỷ, huy động vốn khủng                                                                           ... 2021-03-01
#
# [10 rows x 11 columns]

# %% [markdown]
# # **Xác định chủ đề chính trong n mô tả của n bài báo**

# %%
# Out:
# Processing step 1: Lower case
# Done ---- >>> Next step:
# Processing step 2: Removed Https tag
# Done ---- >>> Next step:
# Processing step 3: Tokenize lớp thứ 1
# Processing step 4: Tokenize lớp thứ 2
# Done.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 331 ms, sys: 0 ns, total: 331 ms
# Wall time: 332 ms

# %% [markdown]
# ### **Xác định danh từ riêng**

# %%
# Out:
# Np < 100? if No -> adjust iloc
#      0
# 1
# Np  33

# %% [markdown]
# # **Graph Keyword Cluster**
