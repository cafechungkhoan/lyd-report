# %% [markdown]
# <a href="https://colab.research.google.com/github/cafechungkhoan/lyd-report/blob/main/DXS_09102021_Comment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LYD - Comment Sentiment Analysis**
#
# *LYD là hệ thống áp dụng Deep Learning dùng để quét, tóm tắt, phân tích và dự báo cảm xúc của nhà đầu tư. Với mục đích hỗ trợ nghiệp vụ tư vấn IR (Investor Relation)*
#
# **Dữ liệu input**:
# là dữ liệu bình luận (text) của nhà đầu tư trên mạng xã hội và các diễn đàn chứng khoán lớn. Quy mô tracking 700k user
#
# **Các Model áp dụng**:
# Bert, transformer, SVM, PhoBERT
#
# ### **LYD trả lời các câu hỏi chính**:
# * **Mã cổ phiếu của doanh nghiệp có được nhà đầu tư yêu thích không?** (Áp dụng Text Classification Model xác định trạng thái cảm xúc của nhà đầu tư hiện tại là tích cực (hài lòng) hay tiêu cực (không hài lòng) về cổ phiếu YYY được xác định trước.)
# * **Nhà đầu tư đang bàn tán gì về cổ phiếu doanh nghiệp?** (Áp dụng Topic Cluster Model phân loại các chủ đề chính cơ bản / kĩ thuật / thời sự & vĩ mô / tin đồn) của cổ phiếu YYY được xác định trước.)
# * **Đâu là chủ đề nhà đầu tư thích nhất về cổ phiếu?** (Áp dụng BERT Text Summarize để tóm tắt nội dung comment)
#
# ---

# %%
#@title Input Parameter
a = input('Nhập mã cần search: ')
b= input('Nhập giới hạn comment: ')
# Out:
# Nhập mã cần search: DXS
# Nhập giới hạn comment: 1000

# %% [markdown]
# ## **Phân tích người tham gia bình luận**
#
# Ý nghĩa của biểu đồ: Biểu diễn bằng chart violin, quan sát mật độ phân phối số lượng bình luận của các user
# *   Xác định có vấn đề seeding bình luận ảo không
# *   Xác định nhóm người theo sentiment

# %%
# Out:
# Số bình luận =  328 . Số người tham gia bình luận =  207 . Median comment / user =  1.0
# Text(0.5, 1.0, 'ViolinPlot số lượng comment của người tham gia bình luận')

# %% [markdown]
# # **Visualize Sentiment Analysis**
#
# Ý nghĩa của biểu đồ: Biểu diễn số lượng bình luận tích cực / tiêu cực / trung tính theo khung thời gian.
# * Positive Comment: Bình luận được máy nhận diện là tích cực
# * Negative Comment: Bình luận được máy nhận diện là tiêu cực
# * Neutral Comment: Bình luận được máy nhận diện là không có trạng thái cảm xúc (hoặc máy không nhận diện được)

# %% [markdown]
# # **Visualize Topic Cluster**
#
# Ý nghĩa biểu đồ: Phân loại comment theo 4 nhóm: Cơ bản / Kĩ thuật / Vĩ mô / Tin đồn. Và nhận diện cảm xúc (tích cực / tiêu cực) trên từng loại topic

# %%
# Out:
# Text(0.5, 1.0, 'Topic Tin đồn')

# %%
# Out:
# Số comment cơ bản =  43 . Số người tham gia comment =  35
# Số comment kĩ thuật =  18 . Số người tham gia comment =  12
# Số comment thời sự & vĩ mô =  8 . Số người tham gia comment =  7
# Số comment tin đồn =  44 . Số người tham gia comment =  41

# %% [markdown]
# ## **Text Summarization (tin đồn) using BERT**

# %%
# Out:
#     index  ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Text_Summarize
# 0   0      ...  DXG trong năm 2021 đã ăn gạch đá quá nhiều từ giới đầu tư chứng khoán, tuy nhiên sau cơn mưa trời lại sáng. Trong khi đó DXG có rất nhiều ưu thế về BĐS tại các tỉnh này, đặc biệt là ở miền Nam khi có nhiều dự án đang triển khai hoặc sắp chào bán. [​IMG]​\n\n3. Biến số đến từ nguồn tiền khủng, tài chính mạnh mẽ đủ sức để triển khai các dự án lớn trong tương lai. Việc DXG mua lại trái phiếu trước hạn tận 8 tháng cũng thể hiện tiềm lực mạnh mẽ của DXG, quyết tâm giảm nợ vay về mức thấp nhất, đồng thời theo đánh giá của tôi thì cũng góp phần giảm lãi DXG phải trả khi chỉ chịu thêm mức phạt 1%. 5. Liệu điều này có khiến bạn phải lăn tăn?
# 1   10     ...  Anh E gom đủ chưa để bảo lái đánh lên nào?
# 2   16     ...  Ông Bùi Ngọc Đức, Tổng Giám Đốc Tập đoàn Đất Xanh đã phát biểu trong buổi họp mặt online với toàn thể CBNV: “Lịch sử thế giới đã chứng mình, sau mỗi đại dịch, mỗi thảm họa, con người chưa bao giờ ngừng lại mà luôn duy trì nhịp sống, tăng trưởng và phát triển. Chính vì vậy, bước qua những sự trì hoãn, sự do dự sau những tháng ngày giãn cách, ngay trong tháng 10, Tập đoàn Đất Xanh sẽ liên tiếp triển khai nhiều kế hoạch, nhiều dự án siêu phẩm mới với quy mô và tầm vóc hoành tráng hơn, ấn tượng hơn.
# 3   28     ...  ... biết khi nào mới cho nhà đầu tư về bờ, 6 tháng tin tưởng lãnh đạo, tin tưởng cty mà cho họ mất nhà thì ... bao giờ có lần thứ 2\nXin gửi đến ban lãnh đạo cty DXS
# 4   59     ...  Con hàng nhọ nhất hệ mặt trời.
# 5   63     ...  𝗡𝗵𝗮̣̂𝗻 đ𝗶̣𝗻𝗵 𝘁𝗵𝗶̣ 𝘁𝗿𝘂̛𝗼̛̀𝗻𝗴 𝟯𝟬/𝟬𝟴:\n- Vnindex đóng cửa tăng +12.08 điểm (+0.93%) lên 1313.02 điểm. - Giao dịch khối ngoại bán ròng -384.84 tỷ tập trung chủ yếu VJC,PNJ,HPG. - Tự doanh bán ròng chủ yếu các mã CTG,MBB,VPB.
# 6   64     ...  📈𝗡𝗵𝗮̣̂𝗻 đ𝗶̣𝗻𝗵 𝘁𝗵𝗶̣ 𝘁𝗿𝘂̛𝗼̛̀𝗻𝗴 𝟮𝟳/𝟬𝟴:📈\n- Vnindex đóng cửa giảm -8.43 điểm (-0.64%) về 1301.12 điểm. - Về dòng tiền tuy có áp lực bán từ VN30 và Bank nhưng dòng tiền cũng dịch chuyển sang các nhóm ngành khác như Cảng, dệt may, đạm, năng lượng ... chứ không có dấu hiệu rút ra khỏi thị trường.
# 25  213    ...  Bàn về DXS\n\n- Người mua IPO: buồn bực vì cổ phiếu lên sàn = giá IPO, biết thế chờ lên sàn rồi hẵng mua, đỡ kẹp lâu. Một kiểu nữa là mong nó sàn vài cây để hốt nên hùa theo dìm. - Về lùm xùm tai tiếng: Nếu ai làm tư vấn niêm yết và làm dịch vụ tạo thanh khoản cho cổ phiếu trên sàn, đều biết để 1 cổ phiếu được nhiều người biết tới, bàn tán, bình phẩm, khen chê, tò mò, quan tâm nhiều như DXS là cực khó, mất vài năm trên sàn, biết bao nhiêu báo cáo định giá, bao nhiêu đội nhóm, zalo room phím hàng, lùa gà .... may ra mới có lượng cầu lớn như vậy. #HoangMai #ChungKhoanVietNam #DXS #IPO
# 26  216    ...  Có sàn 10 phiên e cũng ko mua thề... lãnh đạo bần còn bẩn nữa ... chúc dxs về giá dưới 10k
# 27  217    ...  Con này phải sàn 10 phiên, lãnh đạo DXG cũng là 1 thôi, bản chất rồi
# 28  219    ...  Mọi người nên chọn các công ty tốt lãnh đạo có tâm có tầm để đầu tư tránh các công ty có lãnh đạo lươn lẹo , lừa dối nhà đầu tư như trường hợp của Lươn Trí Thìn.
# 29  220    ...  Mấy ông đang giữ hàng chắc đang mong nó lên lắm đúng không nếu cty có ban lãnh đạo tốt thì tím phiên này, còn đối với thằng lươn này thì 3 key sàn nhé, mai ai thoát được thoát sớm, cty mẹ nó còn giá 22 mà dxs này 15
# 30  224    ...  Con hàng rẻ rách + lái lợn bẩn thỉu nhà DXG cũng đòi ipo giá 32. Ae tẩy chay mạnh loại cp dxg dxs này ra nhé
# 31  236    ...  Lãnh đạo cứ tối ngày bắt tay Lươn Capital để úp bô nhỏ lẻ, tư xả sàn 3 phiên đến IPO cung úp nốt. Dĩ nhiên ai cũng biết hành động dơ bẩn này là đạp gom giá rẻ xong lại bơm thổi lên cho ai ko hiểu thì tham đu vô.
# 32  250    ...  Nó cho mấy bố vào xong nó úp bô. ...
# 33  256    ...  Thông cảm cho NĐT mua IPO DXS. Om vốn mấy tháng trời, lên sàn đúng thời điểm chỉnh giảm mạnh của TT.
# 34  259    ...  Nhĩn DXG làm gương, lãnh đạo là một cái quan trọng nhất để đầu tư vào cổ phiếu đặc biệt ở Việt Nam
# 35  260    ...  😂 Ai vừa ôm 40x thế. Mé bán giấy ko.
# 36  265    ...  Các bác cho e hỏi con này với con DXG thì khác gì nhau, hay kiểu một vỏ 2 lòng.
# 37  276    ...  Ipo này cứ úp bô về giá 12-15 cũng lời chán
# 38  277    ...  Cho nó về giá 10 đi, đi lùa gà ah.
# 39  279    ...  Bị họ nhà Lươn ... úp bô roài.
# 40  294    ...  Tay trái qua tay phải dụ gà thôi.
# 41  306    ...  con này đáng giá penny 7.x vì ... có trò gì.
# 42  311    ...  Anh Thìn lại bỏ tiền ra lùa gà
# 43  327    ...  None
#
# [44 rows x 5 columns]
