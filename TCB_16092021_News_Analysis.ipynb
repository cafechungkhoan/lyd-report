# %% [markdown]
# <a href="https://colab.research.google.com/github/cafechungkhoan/lyd-report/blob/main/TCB_16092021_News_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LYD - News Auto Report**
#
# * Xác định số lượng bài báo theo thời gian
# * Xác định độ yêu thích bài báo theo thời gian
# * Xác định các nguồn đăng của bài báo
# * Topic Cluster & Keyword Maps

# %%
a = input('Nhập mã cần search: ')
# Out:
# Nhập mã cần search: tcb

# %%
# Out:
#                                                                                                                                                            title  ...      month
# 0   TCB: Khát vọng mới của Techcombank                                                                                                                            ... 2021-09-01
# 1   TCB: VDSC - Techcombank có thể lãi 1 tỷ USD năm nay                                                                                                           ... 2021-09-01
# 2   NLG: Công ty chứng khoán 'ôm' trọn 950 tỉ đồng trái phiếu của NLG                                                                                             ... 2021-09-01
# 3   TCB: Nghị quyết HĐQT về việc phê duyệt giao dịch với Người có liên quan                                                                                       ... 2021-09-01
# 4   TCB: Đính chính thông báo giao dịch cổ phiếu ESOP của Người nội bộ Thái Hà Linh                                                                               ... 2021-09-01
# 5   TCB: Nghị quyết HĐQT về việc giao dịch cấp hạn mức thẻ tín dụng với Ông Hoàng Huy Trung                                                              ... 2021-09-01
# 6   TCB: Nghị quyết HĐQT về việc giao dịch cấp hạn mức thẻ tín dụng với Bà Bùi Thị Hồng Mai                                                           ... 2021-09-01
# 7   TCB: Thông báo giao dịch cổ phiếu ESOP của Người nội bộ và người có liên quan đến người nội bộ                                                                ... 2021-09-01
# 8   Còn cơ sở để kỳ vọng cổ phiếu ngân hàng?                                                                                                                      ... 2021-09-01
# 9   TCB: Techcombank sắp phát hành 6 triệu cổ phiếu ESOP                                                                                                          ... 2021-09-01
# 10  TCB: Thông báo phát hành cổ phiếu theo chương trình lựa chọn cho người lao động                                                                               ... 2021-09-01
# 11  TCB: Nghị quyết HĐQT về việc giao dịch cấp hạn mức thẻ tín dụng cho người có liên quan                                                                        ... 2021-09-01
# 12  Lai lịch khủng chủ nhãn hiệu mì 3 miền, Reeva: Sở hữu gần 3.000 tỷ đồng cổ phiếu VIB, có thêm Chứng khoán TCB làm cổ đông bên cạnh NĐT ngoại nắm 49% cổ phần  ... 2021-08-01
# 13  Techcombank, VPBank có thể tái đàm phán bancassurance với phí trả trước cao hơn nhiều lần?                                                                    ... 2021-08-01
# 14  Techcombank cấp hạn mức thẻ tín dụng với Chủ tịch Masan và hai cá nhân, tổ chức                                                                               ... 2021-08-01
# 15  TCB: Nghị quyết HĐQT về việc phê duyệt giao dịch giữa TCB và người có liên quan                                                                               ... 2021-08-01
# 16  Thù lao các ông chủ ngân hàng tăng mạnh, đại gia Dương Công Minh dẫn đầu về thu nhập "khủng"                                                                  ... 2021-08-01
# 17  TCB: Nghị quyết HĐQT về việc phê duyệt giao dịch giữa TCB và MSC                                                                                              ... 2021-08-01
# 18  TCB: Nghị quyết HĐQT về việc phê duyệt giao dịch cấp hạn mức thẻ tín dụng giữa TCB và khách hàng Phùng Quang Hưng                                             ... 2021-08-01
# 19  TCB:  Nghị quyết HĐQT về việc phê duyệt giao dịch cấp hạn mức thẻ tín dụng giữa TCB và khách hàng Nguyễn Đăng Quang                                           ... 2021-08-01
# 20  TCB: 'Bật mí' gia đình quyền lực của tỷ phú Hồ Hùng Anh ở Techcombank                                                                                         ... 2021-08-01
# 21  Lợi nhuận doanh nghiệp quý III/2021 sẽ ‘nhiều màu xám hơn’ vì Covid-19                                                                                        ... 2021-08-01
# 22  Chuyện đại gia bất động sản góp vốn tại ngân hàng                                                                                                             ... 2021-08-01
# 23  TCB: Quyết định của HĐQT về việc thay đổi địa chỉ Chi nhánh Nam Định                                                                                          ... 2021-08-01
# 24  TCB: Báo cáo kết quả giao dịch cổ phiếu của người có liên quan đến Người nội bộ Phùng Thị Thu Hồng và Phùng Thị Mai Hương                                     ... 2021-08-01
# 25  MBKE - 3 cổ phiếu ngân hàng được khuyến nghị cho nửa cuối năm gồm TCB, VCB và VPB                                                                             ... 2021-08-01
# 26  Những người con nghìn tỷ 'ngậm thìa vàng' ở Việt Nam: Nắm giữ hàng triệu cổ phiếu từ Techcombank, Hòa Phát, VPBank đến TPBank                                 ... 2021-08-01
# 27  TCB: Quyết định của HĐQT về việc thay đổi địa chỉ phòng giao dịch Khương Mai                                                                                  ... 2021-08-01
# 28  TCB: Quyết định của HĐQT về việc thay đổi địa chỉ phòng giao dịch Trần Phú                                                                                    ... 2021-08-01
# 29  TCB: Quyết định của HĐQT về việc thay đổi địa chỉ phòng giao dịch Diễn Châu                                                                                   ... 2021-08-01
#
# [30 rows x 11 columns]

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 13 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## **Xác định topic được yêu thích (top like, feedback)**

# %%
data.sort_values('totalLikes', ascending=False).head(10)
# Out:
#                                                                                                                                                 title  ...      month
# 258  Điểm tin tài chính ngày 11/12/2020                                                                                                                ... 2020-12-01
# 44   TCB: Techcombank báo lãi trước thuế 11.500 tỷ đồng trong 6 tháng đầu năm                                                                          ... 2021-07-01
# 1    TCB: VDSC - Techcombank có thể lãi 1 tỷ USD năm nay                                                                                               ... 2021-09-01
# 25   MBKE - 3 cổ phiếu ngân hàng được khuyến nghị cho nửa cuối năm gồm TCB, VCB và VPB                                                                 ... 2021-08-01
# 71   TCB: Lợi nhuận quý 2 của TCB có thể tăng 57%, đạt gần 5.700 tỷ đồng                                                                               ... 2021-07-01
# 86   Các ngân hàng chờ được… nhúng                                                                                                                     ... 2021-06-01
# 68   TCB: Động lực nào khiến TCB của Techcombank bay cao trong phiên 5/7?                                                                              ... 2021-07-01
# 215  TCB: Năm 2020, Techcombank đạt 15.800 tỷ đồng lợi nhuận, vượt 21,5% chỉ tiêu                                                                      ... 2021-01-01
# 130  Nhịp đập thị trường-6/5/2021: Dòng tiền bắt đầu phân hóa rõ ràng. Nhóm ngành Ngân hàng, thép nổi sóng nâng đỡ thị trường. Cập nhật: cổ phiếu TCB  ... 2021-05-01
# 64   TCB: Con gái Chủ tịch Techcombank Hồ Hùng Anh đăng ký mua hơn 22 triệu cổ phiếu TCB                                                               ... 2021-07-01
#
# [10 rows x 11 columns]

# %% [markdown]
# # **Xác định chủ đề chính trong n mô tả của n bài báo**

# %% [markdown]
# # **Graph Keyword Cluster**
